# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sm
from scipy import stats

import statsmodels as sm

from statsmodels.stats.weightstats import ttest_ind

# importing dataset

df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
# Created a new DataFrame for houses sold twice
houses_sold_twice = df[df.duplicated(['id'], keep= False)]
houses_sold_twice
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 93     6021501535   7/25/2014   430000.0         3       1.50         1580
# 94     6021501535  12/23/2014   700000.0         3       1.50         1580
# 313    4139480200   6/18/2014  1380000.0         4       3.25         4290
# 314    4139480200   12/9/2014  1400000.0         4       3.25         4290
# 324    7520000520    9/5/2014   232000.0         2       1.00         1240
# ...           ...         ...        ...       ...        ...          ...
# 20654  8564860270   3/30/2015   502000.0         4       2.50         2680
# 20763  6300000226   6/26/2014   240000.0         4       1.00         1200
# 20764  6300000226    5/4/2015   380000.0         4       1.00         1200
# 21564  7853420110   10/3/2014   594866.0         3       3.00         2780
# 21565  7853420110    5/4/2015   625000.0         3       3.00         2780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [markdown]
# # Question

# %%
# How do I create a new column on the initial DataFrame  df that has a 'one' for all the ids in df that are appearing in houses_sold_twice  

df['sold_twice'] = df[df['id'].isin(houses_sold_twice['id']) == 1]

# df['sold_twice'] = df['id'].map(lambda x: x.isin(houses_sold_twice['id']))

# df['sold_twice'] = [True if x in (houses_sold_twice['id']) else False for x in df['id']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sold_twice'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
